# %%
# Importing the Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading the dataset (CS - Customer Segmentation)

CS = pd.read_csv(r"C:\Users\Shashi\Downloads\Test.csv")

# %%
# Checking the Head of data

CS.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  458989  Female          Yes   36       Yes    Engineer              0.0
# 1  458994    Male          Yes   37       Yes  Healthcare              8.0
# 2  458996  Female          Yes   69        No         NaN              0.0
# 3  459000    Male          Yes   59        No   Executive             11.0
# 4  459001  Female           No   19        No   Marketing              NaN
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          1.0  Cat_6            B
# 1        Average          4.0  Cat_6            A
# 2            Low          1.0  Cat_6            A
# 3           High          2.0  Cat_6            B
# 4            Low          4.0  Cat_6            A

# %%
# Checking the shape of data

CS.shape
# Out:
# (2627, 11)

# %%
# Checking the Datatypes

CS.dtypes
# Out:
# ID                   int64
# Gender              object
# Ever_Married        object
# Age                  int64
# Graduated           object
# Profession          object
# Work_Experience    float64
# Spending_Score      object
# Family_Size        float64
# Var_1               object
# Segmentation        object
# dtype: object

# %%
# Droping the UN-Related Column

CS = CS.drop('ID', axis = 1)

# %%
CS
# Out:
#       Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0     Female          Yes   36       Yes       Engineer              0.0
# 1       Male          Yes   37       Yes     Healthcare              8.0
# 2     Female          Yes   69        No            NaN              0.0
# 3       Male          Yes   59        No      Executive             11.0
# 4     Female           No   19        No      Marketing              NaN
# ...      ...          ...  ...       ...            ...              ...
# 2622    Male           No   29        No     Healthcare              9.0
# 2623  Female           No   35       Yes         Doctor              1.0
# 2624  Female           No   53       Yes  Entertainment              NaN
# 2625    Male          Yes   47       Yes      Executive              1.0
# 2626  Female           No   43       Yes     Healthcare              9.0
#
#      Spending_Score  Family_Size  Var_1 Segmentation
# ...

# %%
# Checking the Value Counts of columns

CS['Gender'].value_counts()
# Out:
# Male      1424
# Female    1203
# Name: Gender, dtype: int64

# %%
CS['Ever_Married'].value_counts()
# Out:
# Yes    1520
# No     1057
# Name: Ever_Married, dtype: int64

# %%
CS['Graduated'].value_counts()
# Out:
# Yes    1602
# No     1001
# Name: Graduated, dtype: int64

# %%
CS['Profession'].value_counts()
# Out:
# Artist           802
# Healthcare       418
# Entertainment    301
# Doctor           242
# Engineer         236
# Lawyer           221
# Executive        176
# Marketing        111
# Homemaker         82
# Name: Profession, dtype: int64

# %%
CS['Spending_Score'].value_counts()
# Out:
# Low        1616
# Average     625
# High        386
# Name: Spending_Score, dtype: int64

# %%
# Checking the duplicates

CS.duplicated().sum()
# Out:
# 22

# %%
CS = CS.drop_duplicates()

# %%
CS.duplicated().sum()
# Out:
# 0

# %%
# Graphical Representation

sns.pairplot(CS)

# %%
# Checking the Zero Variance

CS.var() == 0
# Out:
# C:\Users\Shashi\AppData\Local\Temp\ipykernel_6824\2506325482.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   CS.var() == 0
# Age                False
# Work_Experience    False
# Family_Size        False
# dtype: bool

# %%
# Checking the Missing Values

CS.isna().sum()
# Out:
# Gender               0
# Ever_Married        50
# Age                  0
# Graduated           24
# Profession          38
# Work_Experience    267
# Spending_Score       0
# Family_Size        113
# Var_1               32
# Segmentation         0
# dtype: int64

# %%
CS['Ever_Married'].mode()
# Out:
# 0    Yes
# Name: Ever_Married, dtype: object

# %%
CS['Ever_Married'] = CS['Ever_Married'].fillna('Yes')
# Out:
# C:\Users\Shashi\AppData\Local\Temp\ipykernel_6824\1022127354.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CS['Ever_Married'] = CS['Ever_Married'].fillna('Yes')

# %%
CS['Graduated'].mode()
# Out:
# 0    Yes
# Name: Graduated, dtype: object

# %%
CS['Graduated'] = CS['Graduated'].fillna('Yes')
# Out:
# C:\Users\Shashi\AppData\Local\Temp\ipykernel_6824\743088898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CS['Graduated'] = CS['Graduated'].fillna('Yes')

# %%
CS['Profession'].mode()
# Out:
# 0    Artist
# Name: Profession, dtype: object

# %%
CS['Profession'] = CS['Profession'].fillna('Artist')
# Out:
# C:\Users\Shashi\AppData\Local\Temp\ipykernel_6824\2236743253.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CS['Profession'] = CS['Profession'].fillna('Artist')

# %%
CS['Work_Experience'].mean()
# Out:
# 2.5654405474764754

# %%
CS['Work_Experience'] = CS['Work_Experience'].fillna(2.5654405474764754)
# Out:
# C:\Users\Shashi\AppData\Local\Temp\ipykernel_6824\666234118.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CS['Work_Experience'] = CS['Work_Experience'].fillna(2.5654405474764754)

# %%
CS['Family_Size'].mean()
# Out:
# 2.827046548956661

# %%
CS['Family_Size'] = CS['Family_Size'].fillna(2.827046548956661)
# Out:
# C:\Users\Shashi\AppData\Local\Temp\ipykernel_6824\1669203835.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CS['Family_Size'] = CS['Family_Size'].fillna(2.827046548956661)

# %%
CS['Var_1'].mode()
# Out:
# 0    Cat_6
# Name: Var_1, dtype: object

# %%
CS['Var_1'] = CS['Var_1'].fillna('Cat_6')
# Out:
# C:\Users\Shashi\AppData\Local\Temp\ipykernel_6824\2510366456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CS['Var_1'] = CS['Var_1'].fillna('Cat_6')

# %%
CS.isna().sum()
# Out:
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Profession         0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# Var_1              0
# Segmentation       0
# dtype: int64

# %%
# Dummy Values - Using Label Encoding

from sklearn.preprocessing import LabelEncoder

enc = LabelEncoder()

CS['Gender'] = enc.fit_transform(CS['Gender'])
CS['Ever_Married'] = enc.fit_transform(CS['Ever_Married'])
CS['Graduated'] = enc.fit_transform(CS['Graduated'])
CS['Profession'] = enc.fit_transform(CS['Profession'])
CS['Spending_Score'] = enc.fit_transform(CS['Spending_Score'])
CS['Var_1'] = enc.fit_transform(CS['Var_1'])
CS['Segmentation'] = enc.fit_transform(CS['Segmentation'])
# Out:
# C:\Users\Shashi\AppData\Local\Temp\ipykernel_6824\2651404465.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CS['Gender'] = enc.fit_transform(CS['Gender'])
# C:\Users\Shashi\AppData\Local\Temp\ipykernel_6824\2651404465.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CS['Ever_Married'] = enc.fit_transform(CS['Ever_Married'])
# C:\Users\Shashi\AppData\Local\Temp\ipykernel_6824\2651404465.py:9: SettingWithCopyWarning:
# ...

# %%
CS.head()
# Out:
#    Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0       0             1   36          1           2         0.000000
# 1       1             1   37          1           5         8.000000
# 2       0             1   69          0           0         0.000000
# 3       1             1   59          0           4        11.000000
# 4       0             0   19          0           8         2.565441
#
#    Spending_Score  Family_Size  Var_1  Segmentation
# 0               2          1.0      5             1
# 1               0          4.0      5             0
# 2               2          1.0      5             0
# 3               1          2.0      5             1
# 4               2          4.0      5             0

# %%
# Checking the correlation

CS.corr()
# Out:
#                    Gender  Ever_Married       Age  Graduated  Profession  \
# Gender           1.000000      0.106043  0.013451  -0.055993    0.033872
# Ever_Married     0.106043      1.000000  0.563510   0.192113   -0.097732
# Age              0.013451      0.563510  1.000000   0.228609    0.069599
# Graduated       -0.055993      0.192113  0.228609   1.000000   -0.308099
# Profession       0.033872     -0.097732  0.069599  -0.308099    1.000000
# Work_Experience -0.066148     -0.109017 -0.176636   0.049437   -0.020142
# Spending_Score  -0.046342     -0.606353 -0.282635  -0.136773    0.211851
# Family_Size      0.069788     -0.081169 -0.276071  -0.262136    0.092093
# Var_1            0.028072      0.071483  0.179563   0.145563   -0.030486
# Segmentation    -0.006130     -0.064612 -0.072636  -0.045402    0.074056
#
#                  Work_Experience  Spending_Score  Family_Size     Var_1  \
# Gender                 -0.066148       -0.046342     0.069788  0.028072
# ...

# %%
# Heat Map

fig = plt.figure(figsize = (15,9))
sns.heatmap(CS.corr(), cmap='viridis', annot = True)
# Out:
# <AxesSubplot:>

# %%
# Spliting the data

X = CS.drop('Segmentation', axis = 1)
Y = CS.Segmentation

# %%
# Train_Test_split

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 9, kernel_initializer = 'he_uniform',activation='relu',input_dim = 9))

# Adding the second hidden layer
classifier.add(Dense(units = 4, kernel_initializer = 'he_uniform',activation='relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
model_history=classifier.fit(x_train, y_train,validation_split=0.33, batch_size = 10, epochs = 10)
# Out:
# Epoch 1/10
# 140/140 [==============================] - 2s 7ms/step - loss: 3.0374 - accuracy: 0.3173 - val_loss: 0.7128 - val_accuracy: 0.2631
# Epoch 2/10
# 140/140 [==============================] - 1s 5ms/step - loss: -0.1204 - accuracy: 0.1977 - val_loss: -0.6476 - val_accuracy: 0.2311
# Epoch 3/10
# 140/140 [==============================] - 1s 5ms/step - loss: -1.3529 - accuracy: 0.1963 - val_loss: -1.7519 - val_accuracy: 0.2311
# Epoch 4/10
# 140/140 [==============================] - 1s 5ms/step - loss: -3.0273 - accuracy: 0.1963 - val_loss: -3.7777 - val_accuracy: 0.2311
# Epoch 5/10
# 140/140 [==============================] - 1s 5ms/step - loss: -6.1164 - accuracy: 0.1963 - val_loss: -7.1108 - val_accuracy: 0.2311
# Epoch 6/10
# 140/140 [==============================] - 1s 5ms/step - loss: -9.9014 - accuracy: 0.1963 - val_loss: -10.3202 - val_accuracy: 0.2311
# Epoch 7/10
# ...

# %%
# List all data in history
print(model_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show(block=True)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[105,   0,  16,  51],
#        [ 61,   1,  22,  33],
#        [ 52,   0,  13,  14],
#        [ 72,   2,  11,  68]], dtype=int64)

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.35892514395393477

# %%
# RESULT : I checked the dataset with another Algorithms such as logistic, Decision Tree, Neural Network by mostly all are giving low score so this model is not consider as right fit.
